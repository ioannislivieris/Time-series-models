# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import *
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.utils                   import plot_model


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from   utils.Evaluation                          import RegressionEvaluation
from   utils.LossFunctions                       import *
from   utils.CyclicLR                            import *
from   utils.WarmUpCosineDecayScheduler          import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = 'Data/Austin_Weather.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        = 24
Horizon    =  3
#
epochs     = 100
batch_size =  32

# %% [markdown]
# ## Neural network metrics/loss/optimizer

# %%
# Define NN-metrics
#
metrics = [ 
            MeanAbsolutePercentageError(name="MAPE", dtype=None),
            RootMeanSquaredError(name='RMSE', dtype=None) 
          ]

# Define Loss function
#
loss = SMAPE

# Define Opitmizer
#
optimizer = Adam(learning_rate = 1e-3)

# %% [markdown]
# ## Neural Network callbacks

# %%
# Earlystopping
#
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              min_delta     = 0,
                              patience      = 30,
                              verbose       = 1, 
                              mode          = 'min', 
                              #
                              restore_best_weights = True)
  
    
# Reduce LR on Plateau
#
lrs_scheduler = ReduceLROnPlateau(monitor   = 'val_loss', 
                                  factor     = 0.5,
                                  patience   = 10)

# Cyclic LR
#
CyclicLR_scheduler = CyclicLR(base_lr   = 0.001, 
                              max_lr    = 0.006, 
                              step_size = 2000., 
                              mode      = 'triangular')
# Cosine Decay
#
CosLR__scheduler = WarmUpCosineDecayScheduler(learning_rate_base = 0.001)



# Define callbacks
#
callbacks = [earlystopping, CyclicLR_scheduler]

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))
# Out:
# [INFO] Data imported
# [INFO] Time: 0.01 seconds

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)

df.head(3)
# Out:
#             Temperature [Fahrenheit]  DewPoint [Fahrenheit]  Humidity [%]  \
# Date
# 2013-12-21                        60                   49.0          75.0
# 2013-12-22                        48                   36.0          68.0
# 2013-12-23                        45                   27.0          52.0
#
#             SeaLevelPressure [inches]  Wind [mph]  DayOfWeek  Month
# Date
# 2013-12-21                      29.68         4.0          5     12
# 2013-12-22                      30.13         6.0          6     12
# 2013-12-23                      30.49         3.0          0     12

# %% [markdown]
# ## Set 'target' features

# %%
# Get features
#
Features = ['Temperature [Fahrenheit]', 'DewPoint [Fahrenheit]']

# %% [markdown]
# ### Create new features based on Date

# %%
# df['DayOfWeek'] = df.index.dayofweek
# df['Month']     = df.index.month

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.9 )

df_train = df[ :idx ]
df_test  = df[ idx: ]

# %% [markdown]
# ### Visualization

# %%
for feature in Features:
    
    plt.figure( figsize=(20, 2) )
    
    df_train[feature].plot( color='tab:blue' )
    df_test[feature].plot( color='tab:orange')
    
    plt.legend(['Training', 'Testing'], frameon = False)
    plt.ylabel(feature)
    plt.title('Feature: {}'.format(feature))

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    Value = df.min().min() + 1
    
    df_train = np.log( df_train + Value)
    df_test  = np.log( df_test  + Value)   
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, ForecastingSeries = []):
    
    if (ForecastingSeries == []):
        ForecastingSeries = df.columns
    
    dataX, dataY = [], []
    for i in tqdm( range(df.shape[0] + 1  - Lag - Horizon) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ ForecastingSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df = df_train, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

testX,  testY  = create_dataset(df = df_test, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 1161/1161 [00:00<00:00, 1859.85it/s]
# 100%|██████████| 130/130 [00:00<00:00, 1877.64it/s]
# Training instances:     1161
# Testing instances:       130

# %% [markdown]
# ## Scaling

# %%
# Transform features by scaling each feature to a given range.
#
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scalerX = MinMaxScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scalerX = RobustScaler()
     
    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scalerX = StandardScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'None'):
    print('[WARNING] No data scaling applied.')    
else:
    print('[WARNING] Unknown data scaling. No data scaling applied.')
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# # Forecasting model: Seq2Seq CNN-LSTM

# %% [markdown]
# ## Setup model

# %%
model = Sequential()

model.add( Conv1D(filters = 4, kernel_size = 3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])) )
model.add( Conv1D(filters = 8, kernel_size = 7, activation='relu') )
model.add( MaxPooling1D(pool_size=2) )
#
model.add(Flatten())
#
model.add( RepeatVector( Horizon ) )
model.add( LSTM(200, activation='relu', return_sequences=True) )
#
model.add(TimeDistributed( Dense(100, activation='relu')) )
model.add(TimeDistributed( Dense(trainY.shape[2], activation='linear')) )

model.compile(loss      = loss, 
              optimizer = optimizer, 
              metrics   = metrics)

plot_model(model = model, rankdir = "ΤΒ", show_shapes = True, to_file = './images/Seq2Seq_CNN-LSTM.png', dpi = 60)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = callbacks,
                  verbose          = 1, 
                  validation_split = 0.1)


# Terminate clock
#
print('[INFO] Time = %.2f' % (time.time() - start))
# Out:
# Epoch 1/100
# 33/33 [==============================] - 9s 273ms/step - loss: 0.9413 - MAPE: 84.5212 - RMSE: 4.7626 - val_loss: 0.3085 - val_MAPE: 28.2119 - val_RMSE: 1.3516
# Epoch 2/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1885 - MAPE: 18.6033 - RMSE: 1.0168 - val_loss: 0.1115 - val_MAPE: 12.4146 - val_RMSE: 0.6387
# Epoch 3/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0767 - MAPE: 7.8373 - RMSE: 0.4413 - val_loss: 0.0800 - val_MAPE: 8.6766 - val_RMSE: 0.4468
# Epoch 4/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0494 - MAPE: 5.0568 - RMSE: 0.2862 - val_loss: 0.0670 - val_MAPE: 7.2037 - val_RMSE: 0.3728
# Epoch 5/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0387 - MAPE: 3.9815 - RMSE: 0.2221 - val_loss: 0.0641 - val_MAPE: 6.9747 - val_RMSE: 0.3603
# Epoch 6/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0358 - MAPE: 3.6801 - RMSE: 0.2003 - val_loss: 0.0643 - val_MAPE: 7.0653 - val_RMSE: 0.3719
# Epoch 7/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0342 - MAPE: 3.5170 - RMSE: 0.1920 - val_loss: 0.0584 - val_MAPE: 6.3463 - val_RMSE: 0.3354
# Epoch 8/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0297 - MAPE: 3.0653 - RMSE: 0.1721 - val_loss: 0.0556 - val_MAPE: 5.9561 - val_RMSE: 0.3131
# Epoch 9/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0297 - MAPE: 3.0627 - RMSE: 0.1722 - val_loss: 0.0551 - val_MAPE: 5.9539 - val_RMSE: 0.3199
# Epoch 10/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0284 - MAPE: 2.9252 - RMSE: 0.1658 - val_loss: 0.0557 - val_MAPE: 5.9895 - val_RMSE: 0.3122
# Epoch 11/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0289 - MAPE: 2.9779 - RMSE: 0.1687 - val_loss: 0.0595 - val_MAPE: 6.5342 - val_RMSE: 0.3509
# Epoch 12/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0360 - MAPE: 3.6900 - RMSE: 0.1958 - val_loss: 0.0531 - val_MAPE: 5.6768 - val_RMSE: 0.3015
# Epoch 13/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0295 - MAPE: 3.0402 - RMSE: 0.1688 - val_loss: 0.0556 - val_MAPE: 5.8744 - val_RMSE: 0.3043
# Epoch 14/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0285 - MAPE: 2.9348 - RMSE: 0.1641 - val_loss: 0.0533 - val_MAPE: 5.7487 - val_RMSE: 0.3116
# Epoch 15/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0298 - MAPE: 3.0608 - RMSE: 0.1677 - val_loss: 0.0589 - val_MAPE: 6.1402 - val_RMSE: 0.3058
# Epoch 16/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0275 - MAPE: 2.8275 - RMSE: 0.1591 - val_loss: 0.0567 - val_MAPE: 6.0188 - val_RMSE: 0.3118
# Epoch 17/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0277 - MAPE: 2.8441 - RMSE: 0.1587 - val_loss: 0.0555 - val_MAPE: 5.7882 - val_RMSE: 0.2937
# Epoch 18/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0318 - MAPE: 3.2563 - RMSE: 0.1719 - val_loss: 0.0562 - val_MAPE: 5.9381 - val_RMSE: 0.3102
# Epoch 19/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0267 - MAPE: 2.7423 - RMSE: 0.1539 - val_loss: 0.0540 - val_MAPE: 5.7565 - val_RMSE: 0.3025
# Epoch 20/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0261 - MAPE: 2.6807 - RMSE: 0.1499 - val_loss: 0.0561 - val_MAPE: 5.9544 - val_RMSE: 0.3058
# Epoch 21/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0269 - MAPE: 2.7651 - RMSE: 0.1551 - val_loss: 0.0569 - val_MAPE: 5.9220 - val_RMSE: 0.2977
# Epoch 22/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0275 - MAPE: 2.8154 - RMSE: 0.1563 - val_loss: 0.0570 - val_MAPE: 5.9858 - val_RMSE: 0.3070
# Epoch 23/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0250 - MAPE: 2.5689 - RMSE: 0.1478 - val_loss: 0.0579 - val_MAPE: 6.1413 - val_RMSE: 0.3193
# Epoch 24/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0245 - MAPE: 2.5121 - RMSE: 0.1446 - val_loss: 0.0561 - val_MAPE: 5.9825 - val_RMSE: 0.3099
# Epoch 25/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0285 - MAPE: 2.9231 - RMSE: 0.1590 - val_loss: 0.0647 - val_MAPE: 6.5925 - val_RMSE: 0.3196
# Epoch 26/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0396 - MAPE: 4.0345 - RMSE: 0.2061 - val_loss: 0.0621 - val_MAPE: 6.7494 - val_RMSE: 0.3443
# Epoch 27/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0301 - MAPE: 3.0833 - RMSE: 0.1666 - val_loss: 0.0642 - val_MAPE: 6.5258 - val_RMSE: 0.3167
# Epoch 28/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0256 - MAPE: 2.6239 - RMSE: 0.1475 - val_loss: 0.0602 - val_MAPE: 6.2660 - val_RMSE: 0.3139
# Epoch 29/100
# 33/33 [==============================] - 0s 15ms/step - loss: 0.0242 - MAPE: 2.4841 - RMSE: 0.1417 - val_loss: 0.0565 - val_MAPE: 5.9743 - val_RMSE: 0.3084
# Epoch 30/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0261 - MAPE: 2.6655 - RMSE: 0.1495 - val_loss: 0.0615 - val_MAPE: 6.3307 - val_RMSE: 0.3164
# Epoch 31/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0308 - MAPE: 3.1433 - RMSE: 0.1663 - val_loss: 0.0616 - val_MAPE: 6.3596 - val_RMSE: 0.3142
# Epoch 32/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0244 - MAPE: 2.5086 - RMSE: 0.1427 - val_loss: 0.0575 - val_MAPE: 6.1098 - val_RMSE: 0.3187
# Epoch 33/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0287 - MAPE: 2.9335 - RMSE: 0.1590 - val_loss: 0.0612 - val_MAPE: 6.3696 - val_RMSE: 0.3269
# Epoch 34/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0249 - MAPE: 2.5575 - RMSE: 0.1433 - val_loss: 0.0611 - val_MAPE: 6.4034 - val_RMSE: 0.3261
# Epoch 35/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0238 - MAPE: 2.4394 - RMSE: 0.1387 - val_loss: 0.0587 - val_MAPE: 6.1948 - val_RMSE: 0.3167
# Epoch 36/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0263 - MAPE: 2.6901 - RMSE: 0.1481 - val_loss: 0.0609 - val_MAPE: 6.2606 - val_RMSE: 0.3152
# Epoch 37/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0248 - MAPE: 2.5466 - RMSE: 0.1423 - val_loss: 0.0588 - val_MAPE: 6.0468 - val_RMSE: 0.3055
# Epoch 38/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0286 - MAPE: 2.9172 - RMSE: 0.1540 - val_loss: 0.0630 - val_MAPE: 6.5114 - val_RMSE: 0.3262
# Epoch 39/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0230 - MAPE: 2.3491 - RMSE: 0.1333 - val_loss: 0.0629 - val_MAPE: 6.5094 - val_RMSE: 0.3332
# Epoch 40/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0239 - MAPE: 2.4499 - RMSE: 0.1357 - val_loss: 0.0721 - val_MAPE: 7.2720 - val_RMSE: 0.3590
# Epoch 41/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0268 - MAPE: 2.7419 - RMSE: 0.1465 - val_loss: 0.0590 - val_MAPE: 6.0760 - val_RMSE: 0.3042
# Epoch 42/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0242 - MAPE: 2.4749 - RMSE: 0.1369Restoring model weights from the end of the best epoch.
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0242 - MAPE: 2.4749 - RMSE: 0.1369 - val_loss: 0.0627 - val_MAPE: 6.5374 - val_RMSE: 0.3372
# Epoch 00042: early stopping
# [INFO] Time = 37.22

# %% [markdown]
# ## Training performance

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(20, 4))

ax[0].plot( score.history['RMSE']     );
ax[0].plot( score.history['val_RMSE'] );
ax[0].legend(['Training', 'Validation'], frameon=False);
ax[0].set_xlabel('Epochs');
ax[0].set_ylabel('RMSE');

ax[1].plot( score.history['MAPE']     );
ax[1].plot( score.history['val_MAPE'] );
ax[1].legend(['Training', 'Validation'], frameon=False);
ax[1].set_xlabel('Epochs');
ax[1].set_ylabel('MAPE');

# %% [markdown]
# ## Save forecasting model

# %%
# Save model
#
model.save('models/Seq2Seq_CNN-LSTM.hdf5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
y_pred = model.predict( testX )

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
for idx, feature in enumerate(Features):
    
    print('[INFO] Feature: ', feature)
    print('------------------------------------------------')
    Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
        
        
        
        # Evaluation
        #
        MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )
        
        # Store results
        #
        Performance_Foresting_Model['RMSE']    += [ RMSE    ]
        Performance_Foresting_Model['MAE']     += [ MAE     ]
        Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
        Performance_Foresting_Model['R2']      += [ R2      ]
        
        # Present results
        #
        print('Horizon: ', i)
        print('> RMSE:  ', RMSE)
        print('> SMAPE: ', SMAPE)
        print('> R2:    ', R2)
        print()
# Out:
# [INFO] Feature:  Temperature [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   8.494177674530562
# > SMAPE:  8.736632455697459
# > R2:     -0.21630111928545137
#
# Horizon:  1
# > RMSE:   5.727633304926384
# > SMAPE:  5.932588076816421
# > R2:     0.4579539223176594
#
# Horizon:  2
# > RMSE:   5.086960912976191
# > SMAPE:  5.327739515477106
# > R2:     0.5745165825448653
#
# [INFO] Feature:  DewPoint [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   7.664087705148157
# > SMAPE:  9.972966853662038
# > R2:     0.09536383432720874
#
# Horizon:  1
# > RMSE:   6.833841558651625
# > SMAPE:  8.236323044624363
# > R2:     0.28156219720022724
#
# Horizon:  2
# > RMSE:   6.752362077489506
# > SMAPE:  8.436460681135031
# > R2:     0.2971843856664492

# %% [markdown]
# ## Visualization

# %%
for idx, feature in enumerate(Features):
    
    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
            
            
            
        # Plot Real & Predicted values
        #
        Prices.plot( figsize = (20, 3) )
        #
        plt.title('Feature: {} - Horizon = {}'.format(feature, i+1))
        plt.legend( frameon = False, fontsize = 14)
        plt.xticks(size = 12)
        plt.yticks(size = 12)
        plt.show()
