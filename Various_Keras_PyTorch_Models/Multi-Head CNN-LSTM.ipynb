# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import *
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.utils                   import plot_model


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from   utils.Evaluation                          import RegressionEvaluation
from   utils.LossFunctions                       import *
from   utils.CyclicLR                            import *
from   utils.WarmUpCosineDecayScheduler          import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = 'Data/Austin_Weather.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        = 24
Horizon    =  3
#
epochs     = 100
batch_size =  32

# %% [markdown]
# ## Neural network metrics/loss/optimizer

# %%
# Define NN-metrics
#
metrics = [ 
            MeanAbsolutePercentageError(name="MAPE", dtype=None),
            RootMeanSquaredError(name='RMSE', dtype=None) 
          ]

# Define Loss function
#
loss = SMAPE

# Define Opitmizer
#
optimizer = Adam(learning_rate = 1e-3)

# %% [markdown]
# ## Neural Network callbacks

# %%
# Earlystopping
#
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              min_delta     = 0,
                              patience      = 30,
                              verbose       = 1, 
                              mode          = 'min', 
                              #
                              restore_best_weights = True)
  
    
# Reduce LR on Plateau
#
lrs_scheduler = ReduceLROnPlateau(monitor   = 'val_loss', 
                                  factor     = 0.5,
                                  patience   = 10)

# Cyclic LR
#
CyclicLR_scheduler = CyclicLR(base_lr   = 0.001, 
                              max_lr    = 0.006, 
                              step_size = 2000., 
                              mode      = 'triangular')
# Cosine Decay
#
CosLR__scheduler = WarmUpCosineDecayScheduler(learning_rate_base = 0.001)



# Define callbacks
#
callbacks = [earlystopping, CyclicLR_scheduler]

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))
# Out:
# [INFO] Data imported
# [INFO] Time: 0.01 seconds

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)

df.head(3)
# Out:
#             Temperature [Fahrenheit]  DewPoint [Fahrenheit]  Humidity [%]  \
# Date
# 2013-12-21                        60                   49.0          75.0
# 2013-12-22                        48                   36.0          68.0
# 2013-12-23                        45                   27.0          52.0
#
#             SeaLevelPressure [inches]  Wind [mph]  DayOfWeek  Month
# Date
# 2013-12-21                      29.68         4.0          5     12
# 2013-12-22                      30.13         6.0          6     12
# 2013-12-23                      30.49         3.0          0     12

# %% [markdown]
# ## Set 'target' features

# %%
# Get features
#
Features = ['Temperature [Fahrenheit]', 'DewPoint [Fahrenheit]']

# %% [markdown]
# ### Create new features based on Date

# %%
# df['DayOfWeek'] = df.index.dayofweek
# df['Month']     = df.index.month

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.9 )

df_train = df[ :idx ]
df_test  = df[ idx: ]

# %% [markdown]
# ### Visualization

# %%
for feature in Features:
    
    plt.figure( figsize=(20, 2) )
    
    df_train[feature].plot( color='tab:blue' )
    df_test[feature].plot( color='tab:orange')
    
    plt.legend(['Training', 'Testing'], frameon = False)
    plt.ylabel(feature)
    plt.title('Feature: {}'.format(feature))

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    Value = df.min().min() + 1
    
    df_train = np.log( df_train + Value)
    df_test  = np.log( df_test  + Value)   
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, ForecastingSeries = []):
    
    if (ForecastingSeries == []):
        ForecastingSeries = df.columns
    
    dataX, dataY = [], []
    for i in tqdm( range(df.shape[0] + 1  - Lag - Horizon) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ ForecastingSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df = df_train, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

testX,  testY  = create_dataset(df = df_test, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 1161/1161 [00:00<00:00, 1861.37it/s]
# 100%|██████████| 130/130 [00:00<00:00, 1918.66it/s]
# Training instances:     1161
# Testing instances:       130

# %% [markdown]
# ## Scaling

# %%
# Transform features by scaling each feature to a given range.
#
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scalerX = MinMaxScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scalerX = RobustScaler()
     
    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scalerX = StandardScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'None'):
    print('[WARNING] No data scaling applied.')    
else:
    print('[WARNING] Unknown data scaling. No data scaling applied.')
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# # Forecasting model: Multi-Head CNN-LSTM

# %% [markdown]
# ## Setup model

# %%
Input_layer = Input(shape=(trainX.shape[1], trainX.shape[2])) 

head_list = []
for i in range(0, trainX.shape[2]):
    Conv_layer_head = Conv1D(filters=4, kernel_size=7,  activation='relu')(Input_layer)
    Conv_layer_head = Conv1D(filters=6, kernel_size=11, activation='relu')(Conv_layer_head)
    Conv_layer_flatten = Flatten()(Conv_layer_head)
    head_list.append( Conv_layer_flatten )
    
    
Concat_cnn = Concatenate(axis=1)(head_list)
reshape = Reshape((head_list[0].shape[1], trainX.shape[2]))(Concat_cnn)

lstm = LSTM(100, activation='relu')(reshape)
repeat = RepeatVector( Horizon )(lstm)
lstm_2 = LSTM(100, activation='relu', return_sequences=True)(repeat)
dropout = Dropout(0.2)(lstm_2)
output_layer = Dense(trainY.shape[2], activation='linear')(dropout)

model = Model(inputs=Input_layer, outputs=output_layer)




model.compile(loss      = loss, 
              optimizer = optimizer, 
              metrics   = metrics)

plot_model(model = model, rankdir = "ΤΒ", show_shapes = True, to_file = './images/Multi-Head CNN-LSTM.png', dpi = 60)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = callbacks,
                  verbose          = 1, 
                  validation_split = 0.1)


# Terminate clock
#
print('[INFO] Time = %.2f' % (time.time() - start))
# Out:
# Epoch 1/100
# 33/33 [==============================] - 12s 353ms/step - loss: 1.7081 - MAPE: 36374.9336 - RMSE: 8200.3809 - val_loss: 0.8948 - val_MAPE: 151.1283 - val_RMSE: 12.7800
# Epoch 2/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.7113 - MAPE: 78.7922 - RMSE: 7.0374 - val_loss: 0.2991 - val_MAPE: 31.7980 - val_RMSE: 1.6201
# Epoch 3/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.2841 - MAPE: 28.3155 - RMSE: 1.5509 - val_loss: 0.2319 - val_MAPE: 27.5628 - val_RMSE: 1.3169
# Epoch 4/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.1731 - MAPE: 17.5010 - RMSE: 0.9397 - val_loss: 0.1233 - val_MAPE: 13.9629 - val_RMSE: 0.7897
# Epoch 5/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.1373 - MAPE: 13.8374 - RMSE: 0.7333 - val_loss: 0.1166 - val_MAPE: 13.2250 - val_RMSE: 0.7208
# Epoch 6/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.1210 - MAPE: 12.1552 - RMSE: 0.6338 - val_loss: 0.1321 - val_MAPE: 15.4202 - val_RMSE: 0.8198
# Epoch 7/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.1096 - MAPE: 11.0298 - RMSE: 0.5757 - val_loss: 0.1031 - val_MAPE: 11.7576 - val_RMSE: 0.6467
# Epoch 8/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.1048 - MAPE: 10.5677 - RMSE: 0.5491 - val_loss: 0.1083 - val_MAPE: 12.3194 - val_RMSE: 0.6511
# Epoch 9/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.1019 - MAPE: 10.2737 - RMSE: 0.5314 - val_loss: 0.1098 - val_MAPE: 12.5856 - val_RMSE: 0.6615
# Epoch 10/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0976 - MAPE: 9.8245 - RMSE: 0.5067 - val_loss: 0.0893 - val_MAPE: 9.8979 - val_RMSE: 0.5018
# Epoch 11/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0945 - MAPE: 9.4958 - RMSE: 0.4892 - val_loss: 0.0879 - val_MAPE: 9.7790 - val_RMSE: 0.4988
# Epoch 12/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0913 - MAPE: 9.1840 - RMSE: 0.4749 - val_loss: 0.0993 - val_MAPE: 11.1968 - val_RMSE: 0.5606
# Epoch 13/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0913 - MAPE: 9.1941 - RMSE: 0.4734 - val_loss: 0.1001 - val_MAPE: 11.2265 - val_RMSE: 0.5419
# Epoch 14/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0909 - MAPE: 9.1499 - RMSE: 0.4709 - val_loss: 0.0738 - val_MAPE: 8.1022 - val_RMSE: 0.4174
# Epoch 15/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0893 - MAPE: 8.9793 - RMSE: 0.4598 - val_loss: 0.0759 - val_MAPE: 8.3417 - val_RMSE: 0.4248
# Epoch 16/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0882 - MAPE: 8.8751 - RMSE: 0.4572 - val_loss: 0.0775 - val_MAPE: 8.5845 - val_RMSE: 0.4417
# Epoch 17/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0884 - MAPE: 8.8790 - RMSE: 0.4589 - val_loss: 0.0706 - val_MAPE: 7.6643 - val_RMSE: 0.3903
# Epoch 18/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0887 - MAPE: 8.8897 - RMSE: 0.4534 - val_loss: 0.0778 - val_MAPE: 8.6303 - val_RMSE: 0.4430
# Epoch 19/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0900 - MAPE: 9.0905 - RMSE: 0.4647 - val_loss: 0.0670 - val_MAPE: 7.1823 - val_RMSE: 0.3644
# Epoch 20/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0853 - MAPE: 8.5955 - RMSE: 0.4429 - val_loss: 0.0763 - val_MAPE: 8.4188 - val_RMSE: 0.4248
# Epoch 21/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0870 - MAPE: 8.7304 - RMSE: 0.4502 - val_loss: 0.1037 - val_MAPE: 11.6328 - val_RMSE: 0.5507
# Epoch 22/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0856 - MAPE: 8.6654 - RMSE: 0.4443 - val_loss: 0.0698 - val_MAPE: 7.6283 - val_RMSE: 0.3894
# Epoch 23/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0831 - MAPE: 8.3809 - RMSE: 0.4305 - val_loss: 0.0774 - val_MAPE: 8.5215 - val_RMSE: 0.4241
# Epoch 24/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0819 - MAPE: 8.2541 - RMSE: 0.4222 - val_loss: 0.0670 - val_MAPE: 7.3269 - val_RMSE: 0.3795
# Epoch 25/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0789 - MAPE: 7.9606 - RMSE: 0.4089 - val_loss: 0.0643 - val_MAPE: 6.6524 - val_RMSE: 0.3261
# Epoch 26/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0820 - MAPE: 8.2395 - RMSE: 0.4225 - val_loss: 0.0641 - val_MAPE: 6.6615 - val_RMSE: 0.3296
# Epoch 27/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0795 - MAPE: 8.0109 - RMSE: 0.4132 - val_loss: 0.0771 - val_MAPE: 8.4095 - val_RMSE: 0.4097
# Epoch 28/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0804 - MAPE: 8.1040 - RMSE: 0.4154 - val_loss: 0.0631 - val_MAPE: 6.6612 - val_RMSE: 0.3364
# Epoch 29/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0779 - MAPE: 7.8462 - RMSE: 0.4056 - val_loss: 0.0759 - val_MAPE: 8.4190 - val_RMSE: 0.4300
# Epoch 30/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0788 - MAPE: 7.9310 - RMSE: 0.4087 - val_loss: 0.0635 - val_MAPE: 6.7677 - val_RMSE: 0.3431
# Epoch 31/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0798 - MAPE: 8.0603 - RMSE: 0.4146 - val_loss: 0.0609 - val_MAPE: 6.6136 - val_RMSE: 0.3518
# Epoch 32/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0751 - MAPE: 7.5785 - RMSE: 0.3892 - val_loss: 0.0608 - val_MAPE: 6.5148 - val_RMSE: 0.3379
# Epoch 33/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0754 - MAPE: 7.5839 - RMSE: 0.3939 - val_loss: 0.0629 - val_MAPE: 6.6679 - val_RMSE: 0.3361
# Epoch 34/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0777 - MAPE: 7.8327 - RMSE: 0.4025 - val_loss: 0.0621 - val_MAPE: 6.4859 - val_RMSE: 0.3223
# Epoch 35/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0767 - MAPE: 7.7167 - RMSE: 0.3934 - val_loss: 0.0754 - val_MAPE: 8.1977 - val_RMSE: 0.3979
# Epoch 36/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0762 - MAPE: 7.6962 - RMSE: 0.3950 - val_loss: 0.0610 - val_MAPE: 6.5958 - val_RMSE: 0.3433
# Epoch 37/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0730 - MAPE: 7.3483 - RMSE: 0.3773 - val_loss: 0.0602 - val_MAPE: 6.3479 - val_RMSE: 0.3232
# Epoch 38/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0721 - MAPE: 7.2726 - RMSE: 0.3740 - val_loss: 0.0660 - val_MAPE: 7.1257 - val_RMSE: 0.3628
# Epoch 39/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0715 - MAPE: 7.1873 - RMSE: 0.3692 - val_loss: 0.0641 - val_MAPE: 6.9155 - val_RMSE: 0.3561
# Epoch 40/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0703 - MAPE: 7.0769 - RMSE: 0.3650 - val_loss: 0.0686 - val_MAPE: 7.5376 - val_RMSE: 0.3903
# Epoch 41/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0717 - MAPE: 7.2280 - RMSE: 0.3705 - val_loss: 0.0597 - val_MAPE: 6.4486 - val_RMSE: 0.3429
# Epoch 42/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0710 - MAPE: 7.1535 - RMSE: 0.3684 - val_loss: 0.0674 - val_MAPE: 7.3872 - val_RMSE: 0.3875
# Epoch 43/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0692 - MAPE: 7.0094 - RMSE: 0.3593 - val_loss: 0.0616 - val_MAPE: 6.4560 - val_RMSE: 0.3263
# Epoch 44/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0658 - MAPE: 6.6478 - RMSE: 0.3437 - val_loss: 0.0610 - val_MAPE: 6.4829 - val_RMSE: 0.3340
# Epoch 45/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0669 - MAPE: 6.7501 - RMSE: 0.3490 - val_loss: 0.0617 - val_MAPE: 6.6407 - val_RMSE: 0.3464
# Epoch 46/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0664 - MAPE: 6.7134 - RMSE: 0.3447 - val_loss: 0.0605 - val_MAPE: 6.4675 - val_RMSE: 0.3370
# Epoch 47/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0662 - MAPE: 6.6871 - RMSE: 0.3441 - val_loss: 0.0559 - val_MAPE: 5.9444 - val_RMSE: 0.3117
# Epoch 48/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0688 - MAPE: 6.9656 - RMSE: 0.3556 - val_loss: 0.0613 - val_MAPE: 6.3662 - val_RMSE: 0.3181
# Epoch 49/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0634 - MAPE: 6.4242 - RMSE: 0.3305 - val_loss: 0.0644 - val_MAPE: 7.0185 - val_RMSE: 0.3652
# Epoch 50/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0627 - MAPE: 6.3444 - RMSE: 0.3261 - val_loss: 0.0680 - val_MAPE: 6.9602 - val_RMSE: 0.3371
# Epoch 51/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0645 - MAPE: 6.5032 - RMSE: 0.3338 - val_loss: 0.0579 - val_MAPE: 6.1755 - val_RMSE: 0.3232
# Epoch 52/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0607 - MAPE: 6.1162 - RMSE: 0.3149 - val_loss: 0.0614 - val_MAPE: 6.3701 - val_RMSE: 0.3223
# Epoch 53/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0612 - MAPE: 6.1736 - RMSE: 0.3168 - val_loss: 0.0575 - val_MAPE: 6.0809 - val_RMSE: 0.3156
# Epoch 54/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0606 - MAPE: 6.1408 - RMSE: 0.3160 - val_loss: 0.0582 - val_MAPE: 6.2132 - val_RMSE: 0.3246
# Epoch 55/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0579 - MAPE: 5.8561 - RMSE: 0.3006 - val_loss: 0.0596 - val_MAPE: 6.3483 - val_RMSE: 0.3286
# Epoch 56/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0588 - MAPE: 5.9394 - RMSE: 0.3074 - val_loss: 0.0566 - val_MAPE: 6.0399 - val_RMSE: 0.3183
# Epoch 57/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0569 - MAPE: 5.7529 - RMSE: 0.2945 - val_loss: 0.0586 - val_MAPE: 6.2835 - val_RMSE: 0.3329
# Epoch 58/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0562 - MAPE: 5.6824 - RMSE: 0.2919 - val_loss: 0.0595 - val_MAPE: 6.2926 - val_RMSE: 0.3220
# Epoch 59/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0565 - MAPE: 5.7034 - RMSE: 0.2932 - val_loss: 0.0671 - val_MAPE: 7.2131 - val_RMSE: 0.3622
# Epoch 60/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0564 - MAPE: 5.6938 - RMSE: 0.2926 - val_loss: 0.0589 - val_MAPE: 6.4131 - val_RMSE: 0.3441
# Epoch 61/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0541 - MAPE: 5.4760 - RMSE: 0.2838 - val_loss: 0.0638 - val_MAPE: 6.7090 - val_RMSE: 0.3390
# Epoch 62/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0541 - MAPE: 5.4890 - RMSE: 0.2825 - val_loss: 0.0612 - val_MAPE: 6.4547 - val_RMSE: 0.3295
# Epoch 63/100
# 33/33 [==============================] - 3s 76ms/step - loss: 0.0514 - MAPE: 5.1899 - RMSE: 0.2676 - val_loss: 0.0630 - val_MAPE: 6.5650 - val_RMSE: 0.3280
# Epoch 64/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0509 - MAPE: 5.1422 - RMSE: 0.2643 - val_loss: 0.0583 - val_MAPE: 6.2855 - val_RMSE: 0.3318
# Epoch 65/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0494 - MAPE: 5.0105 - RMSE: 0.2598 - val_loss: 0.0618 - val_MAPE: 6.4933 - val_RMSE: 0.3332
# Epoch 66/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0489 - MAPE: 4.9436 - RMSE: 0.2553 - val_loss: 0.0591 - val_MAPE: 6.2569 - val_RMSE: 0.3248
# Epoch 67/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0477 - MAPE: 4.8282 - RMSE: 0.2499 - val_loss: 0.0596 - val_MAPE: 6.2669 - val_RMSE: 0.3208
# Epoch 68/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0474 - MAPE: 4.7930 - RMSE: 0.2474 - val_loss: 0.0634 - val_MAPE: 6.6994 - val_RMSE: 0.3400
# Epoch 69/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0485 - MAPE: 4.9178 - RMSE: 0.2544 - val_loss: 0.0597 - val_MAPE: 6.2944 - val_RMSE: 0.3230
# Epoch 70/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0456 - MAPE: 4.6143 - RMSE: 0.2384 - val_loss: 0.0623 - val_MAPE: 6.4370 - val_RMSE: 0.3232
# Epoch 71/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0451 - MAPE: 4.5697 - RMSE: 0.2339 - val_loss: 0.0580 - val_MAPE: 6.1302 - val_RMSE: 0.3187
# Epoch 72/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0461 - MAPE: 4.6779 - RMSE: 0.2421 - val_loss: 0.0575 - val_MAPE: 6.1791 - val_RMSE: 0.3304
# Epoch 73/100
# 33/33 [==============================] - 3s 77ms/step - loss: 0.0439 - MAPE: 4.4433 - RMSE: 0.2287 - val_loss: 0.0587 - val_MAPE: 6.2710 - val_RMSE: 0.3278
# Epoch 74/100
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0426 - MAPE: 4.3131 - RMSE: 0.2243 - val_loss: 0.0632 - val_MAPE: 6.7428 - val_RMSE: 0.3418
# Epoch 75/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0433 - MAPE: 4.3937 - RMSE: 0.2258 - val_loss: 0.0622 - val_MAPE: 6.5872 - val_RMSE: 0.3336
# Epoch 76/100
# 33/33 [==============================] - 3s 76ms/step - loss: 0.0431 - MAPE: 4.3723 - RMSE: 0.2267 - val_loss: 0.0582 - val_MAPE: 6.2483 - val_RMSE: 0.3295
# Epoch 77/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0411 - MAPE: 4.1721 - RMSE: 0.2169Restoring model weights from the end of the best epoch.
# 33/33 [==============================] - 3s 78ms/step - loss: 0.0411 - MAPE: 4.1721 - RMSE: 0.2169 - val_loss: 0.0582 - val_MAPE: 6.2677 - val_RMSE: 0.3409
# Epoch 00077: early stopping
# [INFO] Time = 224.13

# %% [markdown]
# ## Training performance

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(20, 4))

ax[0].plot( score.history['RMSE']     );
ax[0].plot( score.history['val_RMSE'] );
ax[0].legend(['Training', 'Validation'], frameon=False);
ax[0].set_xlabel('Epochs');
ax[0].set_ylabel('RMSE');

ax[1].plot( score.history['MAPE']     );
ax[1].plot( score.history['val_MAPE'] );
ax[1].legend(['Training', 'Validation'], frameon=False);
ax[1].set_xlabel('Epochs');
ax[1].set_ylabel('MAPE');

# %% [markdown]
# ## Save forecasting model

# %%
# Save model
#
model.save('models/Multi-Head CNN-LSTM.hdf5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
y_pred = model.predict( testX )

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
for idx, feature in enumerate(Features):
    
    print('[INFO] Feature: ', feature)
    print('------------------------------------------------')
    Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
        
        
        
        # Evaluation
        #
        MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )
        
        # Store results
        #
        Performance_Foresting_Model['RMSE']    += [ RMSE    ]
        Performance_Foresting_Model['MAE']     += [ MAE     ]
        Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
        Performance_Foresting_Model['R2']      += [ R2      ]
        
        # Present results
        #
        print('Horizon: ', i)
        print('> RMSE:  ', RMSE)
        print('> SMAPE: ', SMAPE)
        print('> R2:    ', R2)
        print()
# Out:
# [INFO] Feature:  Temperature [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   12.700737009804245
# > SMAPE:  15.240502422748126
# > R2:     -1.7192946676871426
#
# Horizon:  1
# > RMSE:   10.213071594231735
# > SMAPE:  11.669944800175326
# > R2:     -0.7234494404437741
#
# Horizon:  2
# > RMSE:   10.375646418088007
# > SMAPE:  11.886028231791972
# > R2:     -0.7700933250811011
#
# [INFO] Feature:  DewPoint [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   10.20248746004356
# > SMAPE:  15.12559014838084
# > R2:     -0.6031167555279162
#
# Horizon:  1
# > RMSE:   8.539003406596583
# > SMAPE:  12.188228855810518
# > R2:     -0.12169229980635698
#
# Horizon:  2
# > RMSE:   9.185232335601736
# > SMAPE:  13.242808351516528
# > R2:     -0.30049967911973474

# %% [markdown]
# ## Visualization

# %%
for idx, feature in enumerate(Features):
    
    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
            
            
            
        # Plot Real & Predicted values
        #
        Prices.plot( figsize = (20, 3) )
        #
        plt.title('Feature: {} - Horizon = {}'.format(feature, i+1))
        plt.legend( frameon = False, fontsize = 14)
        plt.xticks(size = 12)
        plt.yticks(size = 12)
        plt.show()
