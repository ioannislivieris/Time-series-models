# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import *
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.utils                   import plot_model


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from   utils.Evaluation                          import RegressionEvaluation
from   utils.LossFunctions                       import *
from   utils.CyclicLR                            import *
from   utils.WarmUpCosineDecayScheduler          import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = 'Data/Austin_Weather.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        = 24
Horizon    =  3
#
epochs     = 100
batch_size =  32

# %% [markdown]
# ## Neural network metrics/loss/optimizer

# %%
# Define NN-metrics
#
metrics = [ 
            MeanAbsolutePercentageError(name="MAPE", dtype=None),
            RootMeanSquaredError(name='RMSE', dtype=None) 
          ]

# Define Loss function
#
loss = SMAPE

# Define Opitmizer
#
optimizer = Adam(learning_rate = 1e-3)

# %% [markdown]
# ## Neural Network callbacks

# %%
# Earlystopping
#
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              min_delta     = 0,
                              patience      = 30,
                              verbose       = 1, 
                              mode          = 'min', 
                              #
                              restore_best_weights = True)
  
    
# Reduce LR on Plateau
#
lrs_scheduler = ReduceLROnPlateau(monitor   = 'val_loss', 
                                  factor     = 0.5,
                                  patience   = 10)

# Cyclic LR
#
CyclicLR_scheduler = CyclicLR(base_lr   = 0.001, 
                              max_lr    = 0.006, 
                              step_size = 2000., 
                              mode      = 'triangular')
# Cosine Decay
#
CosLR__scheduler = WarmUpCosineDecayScheduler(learning_rate_base = 0.001)



# Define callbacks
#
callbacks = [earlystopping, CyclicLR_scheduler]

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))
# Out:
# [INFO] Data imported
# [INFO] Time: 0.01 seconds

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)

df.head(3)
# Out:
#             Temperature [Fahrenheit]  DewPoint [Fahrenheit]  Humidity [%]  \
# Date
# 2013-12-21                        60                   49.0          75.0
# 2013-12-22                        48                   36.0          68.0
# 2013-12-23                        45                   27.0          52.0
#
#             SeaLevelPressure [inches]  Wind [mph]  DayOfWeek  Month
# Date
# 2013-12-21                      29.68         4.0          5     12
# 2013-12-22                      30.13         6.0          6     12
# 2013-12-23                      30.49         3.0          0     12

# %% [markdown]
# ## Set 'target' features

# %%
# Get features
#
Features = ['Temperature [Fahrenheit]', 'DewPoint [Fahrenheit]']

# %% [markdown]
# ### Create new features based on Date

# %%
# df['DayOfWeek'] = df.index.dayofweek
# df['Month']     = df.index.month

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.9 )

df_train = df[ :idx ]
df_test  = df[ idx: ]

# %% [markdown]
# ### Visualization

# %%
for feature in Features:
    
    plt.figure( figsize=(20, 2) )
    
    df_train[feature].plot( color='tab:blue' )
    df_test[feature].plot( color='tab:orange')
    
    plt.legend(['Training', 'Testing'], frameon = False)
    plt.ylabel(feature)
    plt.title('Feature: {}'.format(feature))

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    Value = df.min().min() + 1
    
    df_train = np.log( df_train + Value)
    df_test  = np.log( df_test  + Value)   
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, ForecastingSeries = []):
    
    if (ForecastingSeries == []):
        ForecastingSeries = df.columns
    
    dataX, dataY = [], []
    for i in tqdm( range(df.shape[0] + 1  - Lag - Horizon) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ ForecastingSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df = df_train, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

testX,  testY  = create_dataset(df = df_test, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 1161/1161 [00:00<00:00, 1827.02it/s]
# 100%|██████████| 130/130 [00:00<00:00, 1764.45it/s]
# Training instances:     1161
# Testing instances:       130

# %% [markdown]
# ## Scaling

# %%
# Transform features by scaling each feature to a given range.
#
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scalerX = MinMaxScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scalerX = RobustScaler()
     
    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scalerX = StandardScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'None'):
    print('[WARNING] No data scaling applied.')    
else:
    print('[WARNING] Unknown data scaling. No data scaling applied.')
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# # Forecasting model: Seq2Seq LSTM

# %% [markdown]
# ## Setup model

# %%
model = Sequential()

model.add(LSTM(100, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(64, activation='relu'))
model.add(RepeatVector( Horizon ))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(trainY.shape[2], activation='linear')))


model.compile(loss      = loss, 
              optimizer = optimizer, 
              metrics   = metrics)

plot_model(model = model, rankdir = "ΤΒ", show_shapes = True, to_file = './images/Seq2Seq_LSTM.png', dpi = 60)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = callbacks,
                  verbose          = 1, 
                  validation_split = 0.1)


# Terminate clock
#
print('[INFO] Time = %.2f' % (time.time() - start))
# Out:
# Epoch 1/100
# 33/33 [==============================] - 3s 96ms/step - loss: 1.0553 - MAPE: 110.3872 - RMSE: 11.2660 - val_loss: 0.1602 - val_MAPE: 14.9089 - val_RMSE: 0.7710
# Epoch 2/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0785 - MAPE: 8.1569 - RMSE: 0.5272 - val_loss: 0.0790 - val_MAPE: 8.6544 - val_RMSE: 0.4356
# Epoch 3/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0413 - MAPE: 4.2468 - RMSE: 0.2280 - val_loss: 0.0722 - val_MAPE: 7.4080 - val_RMSE: 0.3605
# Epoch 4/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0396 - MAPE: 4.0692 - RMSE: 0.2169 - val_loss: 0.0711 - val_MAPE: 7.7885 - val_RMSE: 0.4105
# Epoch 5/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0345 - MAPE: 3.5514 - RMSE: 0.1940 - val_loss: 0.0662 - val_MAPE: 7.2358 - val_RMSE: 0.3854
# Epoch 6/100
# 33/33 [==============================] - 3s 83ms/step - loss: 0.0305 - MAPE: 3.1471 - RMSE: 0.1766 - val_loss: 0.0625 - val_MAPE: 6.7780 - val_RMSE: 0.3625
# Epoch 7/100
# 33/33 [==============================] - 3s 83ms/step - loss: 0.0331 - MAPE: 3.4098 - RMSE: 0.1866 - val_loss: 0.0710 - val_MAPE: 7.6768 - val_RMSE: 0.4011
# Epoch 8/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0307 - MAPE: 3.1608 - RMSE: 0.1753 - val_loss: 0.0635 - val_MAPE: 6.8553 - val_RMSE: 0.3669
# Epoch 9/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0329 - MAPE: 3.3778 - RMSE: 0.1830 - val_loss: 0.0665 - val_MAPE: 6.9155 - val_RMSE: 0.3351
# Epoch 10/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0365 - MAPE: 3.7451 - RMSE: 0.1980 - val_loss: 0.0685 - val_MAPE: 7.3769 - val_RMSE: 0.3674
# Epoch 11/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0421 - MAPE: 4.3116 - RMSE: 0.2252 - val_loss: 0.0768 - val_MAPE: 8.5355 - val_RMSE: 0.4644
# Epoch 12/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0329 - MAPE: 3.3782 - RMSE: 0.1847 - val_loss: 0.0539 - val_MAPE: 5.6997 - val_RMSE: 0.2921
# Epoch 13/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0303 - MAPE: 3.1146 - RMSE: 0.1723 - val_loss: 0.0647 - val_MAPE: 6.9261 - val_RMSE: 0.3559
# Epoch 14/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0288 - MAPE: 2.9547 - RMSE: 0.1658 - val_loss: 0.0595 - val_MAPE: 6.4638 - val_RMSE: 0.3362
# Epoch 15/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0288 - MAPE: 2.9597 - RMSE: 0.1644 - val_loss: 0.0622 - val_MAPE: 6.6385 - val_RMSE: 0.3400
# Epoch 16/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0300 - MAPE: 3.0761 - RMSE: 0.1678 - val_loss: 0.0645 - val_MAPE: 7.0567 - val_RMSE: 0.3582
# Epoch 17/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0373 - MAPE: 3.8248 - RMSE: 0.1986 - val_loss: 0.0532 - val_MAPE: 5.5777 - val_RMSE: 0.2841
# Epoch 18/100
# 33/33 [==============================] - 3s 84ms/step - loss: 0.0301 - MAPE: 3.0958 - RMSE: 0.1704 - val_loss: 0.0538 - val_MAPE: 5.5860 - val_RMSE: 0.2809
# Epoch 19/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0250 - MAPE: 2.5776 - RMSE: 0.1504 - val_loss: 0.0574 - val_MAPE: 5.9223 - val_RMSE: 0.2864
# Epoch 20/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0276 - MAPE: 2.8386 - RMSE: 0.1586 - val_loss: 0.0481 - val_MAPE: 5.1376 - val_RMSE: 0.2747
# Epoch 21/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0292 - MAPE: 2.9932 - RMSE: 0.1636 - val_loss: 0.0589 - val_MAPE: 5.9768 - val_RMSE: 0.2918
# Epoch 22/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0324 - MAPE: 3.3108 - RMSE: 0.1731 - val_loss: 0.0497 - val_MAPE: 5.2808 - val_RMSE: 0.2802
# Epoch 23/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0258 - MAPE: 2.6525 - RMSE: 0.1515 - val_loss: 0.0521 - val_MAPE: 5.3900 - val_RMSE: 0.2713
# Epoch 24/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0312 - MAPE: 3.1893 - RMSE: 0.1716 - val_loss: 0.0542 - val_MAPE: 5.8288 - val_RMSE: 0.3079
# Epoch 25/100
# 33/33 [==============================] - 3s 83ms/step - loss: 0.0266 - MAPE: 2.7343 - RMSE: 0.1538 - val_loss: 0.0476 - val_MAPE: 5.0584 - val_RMSE: 0.2760
# Epoch 26/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0264 - MAPE: 2.7052 - RMSE: 0.1509 - val_loss: 0.0527 - val_MAPE: 5.5802 - val_RMSE: 0.2945
# Epoch 27/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0318 - MAPE: 3.2597 - RMSE: 0.1733 - val_loss: 0.0515 - val_MAPE: 5.2884 - val_RMSE: 0.2652
# Epoch 28/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0296 - MAPE: 3.0236 - RMSE: 0.1630 - val_loss: 0.0491 - val_MAPE: 5.1525 - val_RMSE: 0.2741
# Epoch 29/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0256 - MAPE: 2.6251 - RMSE: 0.1483 - val_loss: 0.0525 - val_MAPE: 5.4220 - val_RMSE: 0.2846
# Epoch 30/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0250 - MAPE: 2.5681 - RMSE: 0.1452 - val_loss: 0.0548 - val_MAPE: 5.8817 - val_RMSE: 0.3062
# Epoch 31/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0291 - MAPE: 2.9792 - RMSE: 0.1628 - val_loss: 0.0588 - val_MAPE: 6.0072 - val_RMSE: 0.3075
# Epoch 32/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0232 - MAPE: 2.3844 - RMSE: 0.1388 - val_loss: 0.0521 - val_MAPE: 5.5548 - val_RMSE: 0.2957
# Epoch 33/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0276 - MAPE: 2.8249 - RMSE: 0.1534 - val_loss: 0.0484 - val_MAPE: 5.0814 - val_RMSE: 0.2655
# Epoch 34/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0280 - MAPE: 2.8599 - RMSE: 0.1576 - val_loss: 0.0504 - val_MAPE: 5.3090 - val_RMSE: 0.2738
# Epoch 35/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0235 - MAPE: 2.4027 - RMSE: 0.1373 - val_loss: 0.0557 - val_MAPE: 5.8201 - val_RMSE: 0.2930
# Epoch 36/100
# 33/33 [==============================] - 3s 83ms/step - loss: 0.0234 - MAPE: 2.4015 - RMSE: 0.1377 - val_loss: 0.0556 - val_MAPE: 5.7750 - val_RMSE: 0.2905
# Epoch 37/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0260 - MAPE: 2.6610 - RMSE: 0.1473 - val_loss: 0.0601 - val_MAPE: 6.0846 - val_RMSE: 0.3038
# Epoch 38/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0291 - MAPE: 2.9791 - RMSE: 0.1613 - val_loss: 0.0567 - val_MAPE: 5.9630 - val_RMSE: 0.3056
# Epoch 39/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0232 - MAPE: 2.3801 - RMSE: 0.1348 - val_loss: 0.0557 - val_MAPE: 5.9019 - val_RMSE: 0.3050
# Epoch 40/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0238 - MAPE: 2.4401 - RMSE: 0.1388 - val_loss: 0.0531 - val_MAPE: 5.5419 - val_RMSE: 0.2850
# Epoch 41/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0230 - MAPE: 2.3519 - RMSE: 0.1333 - val_loss: 0.0591 - val_MAPE: 6.0830 - val_RMSE: 0.3010
# Epoch 42/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0242 - MAPE: 2.4757 - RMSE: 0.1389 - val_loss: 0.0579 - val_MAPE: 5.9502 - val_RMSE: 0.2963
# Epoch 43/100
# 33/33 [==============================] - 3s 83ms/step - loss: 0.0215 - MAPE: 2.2033 - RMSE: 0.1268 - val_loss: 0.0556 - val_MAPE: 5.9220 - val_RMSE: 0.3059
# Epoch 44/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0255 - MAPE: 2.6054 - RMSE: 0.1416 - val_loss: 0.0625 - val_MAPE: 6.7136 - val_RMSE: 0.3599
# Epoch 45/100
# 33/33 [==============================] - 3s 79ms/step - loss: 0.0242 - MAPE: 2.4813 - RMSE: 0.1382 - val_loss: 0.0641 - val_MAPE: 6.4566 - val_RMSE: 0.3278
# Epoch 46/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0236 - MAPE: 2.4067 - RMSE: 0.1346 - val_loss: 0.0609 - val_MAPE: 6.4659 - val_RMSE: 0.3306
# Epoch 47/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0231 - MAPE: 2.3630 - RMSE: 0.1308 - val_loss: 0.0587 - val_MAPE: 5.9999 - val_RMSE: 0.3006
# Epoch 48/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0218 - MAPE: 2.2272 - RMSE: 0.1237 - val_loss: 0.0520 - val_MAPE: 5.4777 - val_RMSE: 0.2830
# Epoch 49/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0215 - MAPE: 2.1963 - RMSE: 0.1250 - val_loss: 0.0548 - val_MAPE: 5.6921 - val_RMSE: 0.2946
# Epoch 50/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0222 - MAPE: 2.2723 - RMSE: 0.1285 - val_loss: 0.0608 - val_MAPE: 6.2182 - val_RMSE: 0.3085
# Epoch 51/100
# 33/33 [==============================] - 3s 81ms/step - loss: 0.0231 - MAPE: 2.3597 - RMSE: 0.1325 - val_loss: 0.0606 - val_MAPE: 6.2086 - val_RMSE: 0.3209
# Epoch 52/100
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0197 - MAPE: 2.0180 - RMSE: 0.1170 - val_loss: 0.0569 - val_MAPE: 5.9402 - val_RMSE: 0.2960
# Epoch 53/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0206 - MAPE: 2.1094 - RMSE: 0.1198 - val_loss: 0.0560 - val_MAPE: 5.9463 - val_RMSE: 0.3113
# Epoch 54/100
# 33/33 [==============================] - 3s 80ms/step - loss: 0.0208 - MAPE: 2.1181 - RMSE: 0.1186 - val_loss: 0.0526 - val_MAPE: 5.5498 - val_RMSE: 0.2913
# Epoch 55/100
# 33/33 [==============================] - ETA: 0s - loss: 0.0270 - MAPE: 2.7457 - RMSE: 0.1460Restoring model weights from the end of the best epoch.
# 33/33 [==============================] - 3s 82ms/step - loss: 0.0270 - MAPE: 2.7457 - RMSE: 0.1460 - val_loss: 0.0536 - val_MAPE: 5.7140 - val_RMSE: 0.2995
# Epoch 00055: early stopping
# [INFO] Time = 155.79

# %% [markdown]
# ## Training performance

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(20, 4))

ax[0].plot( score.history['RMSE']     );
ax[0].plot( score.history['val_RMSE'] );
ax[0].legend(['Training', 'Validation'], frameon=False);
ax[0].set_xlabel('Epochs');
ax[0].set_ylabel('RMSE');

ax[1].plot( score.history['MAPE']     );
ax[1].plot( score.history['val_MAPE'] );
ax[1].legend(['Training', 'Validation'], frameon=False);
ax[1].set_xlabel('Epochs');
ax[1].set_ylabel('MAPE');

# %% [markdown]
# ## Save forecasting model

# %%
# Save model
#
model.save('models/Seq2Seq_LSTM.hdf5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
y_pred = model.predict( testX )

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
for idx, feature in enumerate(Features):
    
    print('[INFO] Feature: ', feature)
    print('------------------------------------------------')
    Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
        
        
        
        # Evaluation
        #
        MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )
        
        # Store results
        #
        Performance_Foresting_Model['RMSE']    += [ RMSE    ]
        Performance_Foresting_Model['MAE']     += [ MAE     ]
        Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
        Performance_Foresting_Model['R2']      += [ R2      ]
        
        # Present results
        #
        print('Horizon: ', i)
        print('> RMSE:  ', RMSE)
        print('> SMAPE: ', SMAPE)
        print('> R2:    ', R2)
        print()
# Out:
# [INFO] Feature:  Temperature [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   5.959366870930387
# > SMAPE:  6.105399286829115
# > R2:     0.40131459748531917
#
# Horizon:  1
# > RMSE:   4.9210314616687025
# > SMAPE:  5.208710820906742
# > R2:     0.5998727973436377
#
# Horizon:  2
# > RMSE:   5.805566310812313
# > SMAPE:  6.386888550272767
# > R2:     0.44581468007018965
#
# [INFO] Feature:  DewPoint [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   5.938624256486216
# > SMAPE:  6.8759427458932505
# > R2:     0.45684383948782803
#
# Horizon:  1
# > RMSE:   6.831190536799337
# > SMAPE:  8.226609099986508
# > R2:     0.2821194898673093
#
# Horizon:  2
# > RMSE:   7.885257463113866
# > SMAPE:  9.82475777323394
# > R2:     0.04156709931864189

# %% [markdown]
# ## Visualization

# %%
for idx, feature in enumerate(Features):
    
    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
            
            
            
        # Plot Real & Predicted values
        #
        Prices.plot( figsize = (20, 3) )
        #
        plt.title('Feature: {} - Horizon = {}'.format(feature, i+1))
        plt.legend( frameon = False, fontsize = 14)
        plt.xticks(size = 12)
        plt.yticks(size = 12)
        plt.show()
