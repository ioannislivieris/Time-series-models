# %% [markdown]
# # Libraries

# %% [markdown]
# ##  Remove warnings

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## Import libraries

# %%
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Basic libraries
#
import time
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Visualization library
#
import matplotlib.pyplot   as plt 


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Sklearn library
#
from sklearn.preprocessing import StandardScaler


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Tensorflow library
#
from   tensorflow.keras.models                  import *
from   tensorflow.keras.layers                  import *
from   tensorflow.keras.callbacks               import *
from   tensorflow.keras.metrics                 import *
from   tensorflow.keras.optimizers              import *
from   tensorflow.keras.utils                   import plot_model


# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# User library
#
from   utils.Evaluation                          import RegressionEvaluation
from   utils.LossFunctions                       import *
from   utils.CyclicLR                            import *
from   utils.WarmUpCosineDecayScheduler          import *
from   utils.TemporalConvolutionalLayer          import *

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Data handling parameters

# %%
# Parameters
#
filename   = 'Data/Austin_Weather.csv'

Transformation  = True
Scaling         = 'Standard'

# %% [markdown]
# ## Neural networks parameters

# %%
Lag        = 24
Horizon    =  3
#
epochs     = 100
batch_size =  32

# %% [markdown]
# ## Neural network metrics/loss/optimizer

# %%
# Define NN-metrics
#
metrics = [ 
            MeanAbsolutePercentageError(name="MAPE", dtype=None),
            RootMeanSquaredError(name='RMSE', dtype=None) 
          ]

# Define Loss function
#
loss = SMAPE

# Define Opitmizer
#
optimizer = Adam(learning_rate = 1e-3)

# %% [markdown]
# ## Neural Network callbacks

# %%
# Earlystopping
#
earlystopping = EarlyStopping(monitor       = 'val_loss', 
                              min_delta     = 0,
                              patience      = 30,
                              verbose       = 1, 
                              mode          = 'min', 
                              #
                              restore_best_weights = True)
  
    
# Reduce LR on Plateau
#
lrs_scheduler = ReduceLROnPlateau(monitor   = 'val_loss', 
                                  factor     = 0.5,
                                  patience   = 10)

# Cyclic LR
#
CyclicLR_scheduler = CyclicLR(base_lr   = 0.001, 
                              max_lr    = 0.006, 
                              step_size = 2000., 
                              mode      = 'triangular')
# Cosine Decay
#
CosLR__scheduler = WarmUpCosineDecayScheduler(learning_rate_base = 0.001)



# Define callbacks
#
callbacks = [earlystopping, CyclicLR_scheduler]

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Import data

# %%
# Start timer
#
start = time.time()

# Load data
#
df = pd.read_csv( filename )

print('[INFO] Data imported')
print('[INFO] Time: %.2f seconds' % (time.time() - start))
# Out:
# [INFO] Data imported
# [INFO] Time: 0.01 seconds

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# ### Set index

# %%
# Convert Date to 'datetime64'
#
df['Date'] = df['Date'].astype('datetime64')

# Set index
#
df.set_index('Date', inplace=True)

df.head(3)
# Out:
#             Temperature [Fahrenheit]  DewPoint [Fahrenheit]  Humidity [%]  \
# Date
# 2013-12-21                        60                   49.0          75.0
# 2013-12-22                        48                   36.0          68.0
# 2013-12-23                        45                   27.0          52.0
#
#             SeaLevelPressure [inches]  Wind [mph]  DayOfWeek  Month
# Date
# 2013-12-21                      29.68         4.0          5     12
# 2013-12-22                      30.13         6.0          6     12
# 2013-12-23                      30.49         3.0          0     12

# %% [markdown]
# ## Set 'target' features

# %%
# Get features
#
Features = ['Temperature [Fahrenheit]', 'DewPoint [Fahrenheit]']

# %% [markdown]
# ### Create new features based on Date

# %%
# df['DayOfWeek'] = df.index.dayofweek
# df['Month']     = df.index.month

# %% [markdown]
# ### Split Training/Testing

# %%
idx = int( df.shape[0] * 0.9 )

df_train = df[ :idx ]
df_test  = df[ idx: ]

# %% [markdown]
# ### Visualization

# %%
for feature in Features:
    
    plt.figure( figsize=(20, 2) )
    
    df_train[feature].plot( color='tab:blue' )
    df_test[feature].plot( color='tab:orange')
    
    plt.legend(['Training', 'Testing'], frameon = False)
    plt.ylabel(feature)
    plt.title('Feature: {}'.format(feature))

# %% [markdown]
# ### Fixing Lag

# %%
df_test = pd.concat([df_train.iloc[-Lag:], df_test])

# %% [markdown]
# ## Data Transformation

# %%
if (Transformation == True):
    
    print('[INFO] Data transformation applied')
    
    Value = df.min().min() + 1
    
    df_train = np.log( df_train + Value)
    df_test  = np.log( df_test  + Value)   
    
else:
    print('[INFO] No data transformation applied.')
# Out:
# [INFO] Data transformation applied

# %% [markdown]
# ## Create Training/Testing data

# %%
def create_dataset(df = None, Lag = 1, Horizon = 12, ForecastingSeries = []):
    
    if (ForecastingSeries == []):
        ForecastingSeries = df.columns
    
    dataX, dataY = [], []
    for i in tqdm( range(df.shape[0] + 1  - Lag - Horizon) ):
        
        dataX.append( df.to_numpy()[i:(i+Lag)] )        
        dataY.append( df[ ForecastingSeries ].to_numpy()[i + Lag : i + Lag + Horizon] )
        
        
    return ( np.array(dataX), np.array(dataY) )

# %%
trainX, trainY = create_dataset(df = df_train, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

testX,  testY  = create_dataset(df = df_test, 
                                Lag = Lag, 
                                Horizon = Horizon, 
                                ForecastingSeries = Features)

print('Training instances:   %6i' % trainX.shape[0])
print('Testing instances:    %6i' % testX.shape[0])
# Out:
# 100%|██████████| 1161/1161 [00:00<00:00, 1768.56it/s]
# 100%|██████████| 130/130 [00:00<00:00, 1900.31it/s]
# Training instances:     1161
# Testing instances:       130

# %% [markdown]
# ## Scaling

# %%
# Transform features by scaling each feature to a given range.
#
if (Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')
    
    # Set scaler
    #
    scalerX = MinMaxScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')
    
    # Set scaler
    #
    scalerX = RobustScaler()
     
    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')
    
    # Set scaler
    #
    scalerX = StandardScaler()

    trainX = scalerX.fit_transform(trainX.reshape(-1, trainX.shape[-1])).reshape(trainX.shape)
    testX  = scalerX.transform(testX.reshape(-1, testX.shape[-1])).reshape(testX.shape)
    
elif (Scaling == 'None'):
    print('[WARNING] No data scaling applied.')    
else:
    print('[WARNING] Unknown data scaling. No data scaling applied.')
# Out:
# [INFO] Scaling: Standard

# %% [markdown]
# # Forecasting model: Temporal Convolutional Network (TCN)

# %% [markdown]
# ## Setup model

# %%
Input_layer = Input(shape=( trainX.shape[1], trainX.shape[2]) )   

x = TCN(nb_filters=32, kernel_size=2, padding='same', activation='relu')(Input_layer)
#
x = Flatten()(x)
#
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

# Output layer
#
x = Dense(Horizon*trainY.shape[2], activation='relu')(x)
Output_layer = Reshape((Horizon, trainY.shape[2]))(x)

model = Model([Input_layer], [Output_layer])



model.compile(loss      = loss, 
              optimizer = optimizer, 
              metrics   = metrics)

plot_model(model = model, rankdir = "ΤΒ", show_shapes = True, to_file = './images/TCN.png', dpi = 60)

# %% [markdown]
# ## Training process

# %%
# Start clock
#
start = time.time()


score = model.fit(trainX, trainY, 
                  epochs           = epochs, 
                  batch_size       = batch_size, 
                  callbacks        = callbacks,
                  verbose          = 1, 
                  validation_split = 0.1)


# Terminate clock
#
print('[INFO] Time = %.2f' % (time.time() - start))
# Out:
# Epoch 1/100
# 33/33 [==============================] - 37s 1s/step - loss: 1.2666 - MAPE: 72.0028 - RMSE: 3.2641 - val_loss: 1.6720 - val_MAPE: 94.9643 - val_RMSE: 3.8880
# Epoch 2/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.8117 - MAPE: 49.2826 - RMSE: 2.5298 - val_loss: 1.8135 - val_MAPE: 95.2572 - val_RMSE: 3.8127
# Epoch 3/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.7198 - MAPE: 45.6673 - RMSE: 2.4055 - val_loss: 1.3526 - val_MAPE: 74.2428 - val_RMSE: 3.2668
# Epoch 4/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.6174 - MAPE: 39.3212 - RMSE: 2.1652 - val_loss: 0.8790 - val_MAPE: 52.2337 - val_RMSE: 2.5516
# Epoch 5/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.5880 - MAPE: 39.4534 - RMSE: 2.1298 - val_loss: 0.6033 - val_MAPE: 36.4348 - val_RMSE: 2.1151
# Epoch 6/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.4706 - MAPE: 32.4552 - RMSE: 1.7995 - val_loss: 0.3277 - val_MAPE: 29.4965 - val_RMSE: 1.7074
# Epoch 7/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.5362 - MAPE: 37.1043 - RMSE: 1.9974 - val_loss: 0.6518 - val_MAPE: 39.0285 - val_RMSE: 2.2129
# Epoch 8/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.4471 - MAPE: 30.4293 - RMSE: 1.7243 - val_loss: 0.4607 - val_MAPE: 29.5437 - val_RMSE: 1.7956
# Epoch 9/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.4410 - MAPE: 30.9690 - RMSE: 1.7659 - val_loss: 0.1192 - val_MAPE: 10.0994 - val_RMSE: 0.7154
# Epoch 10/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.3756 - MAPE: 26.6552 - RMSE: 1.5646 - val_loss: 0.1360 - val_MAPE: 15.3425 - val_RMSE: 0.6778
# Epoch 11/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.3155 - MAPE: 25.4635 - RMSE: 1.4603 - val_loss: 0.2521 - val_MAPE: 30.5797 - val_RMSE: 1.2895
# Epoch 12/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2952 - MAPE: 22.5369 - RMSE: 1.3708 - val_loss: 0.0707 - val_MAPE: 7.6278 - val_RMSE: 0.3927
# Epoch 13/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2599 - MAPE: 20.1759 - RMSE: 1.2698 - val_loss: 0.0842 - val_MAPE: 9.3529 - val_RMSE: 0.4594
# Epoch 14/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.2159 - MAPE: 17.0309 - RMSE: 1.1274 - val_loss: 0.0908 - val_MAPE: 9.4423 - val_RMSE: 0.5292
# Epoch 15/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1950 - MAPE: 15.5190 - RMSE: 1.0702 - val_loss: 0.1448 - val_MAPE: 12.4854 - val_RMSE: 0.8265
# Epoch 16/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1890 - MAPE: 14.5331 - RMSE: 1.0583 - val_loss: 0.0934 - val_MAPE: 10.4314 - val_RMSE: 0.4957
# Epoch 17/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1657 - MAPE: 13.7613 - RMSE: 0.9602 - val_loss: 0.0591 - val_MAPE: 6.4755 - val_RMSE: 0.3473
# Epoch 18/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1335 - MAPE: 13.5974 - RMSE: 1.0414 - val_loss: 0.0789 - val_MAPE: 8.8201 - val_RMSE: 0.4496
# Epoch 19/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1156 - MAPE: 12.3936 - RMSE: 0.9984 - val_loss: 0.0847 - val_MAPE: 9.4386 - val_RMSE: 0.4630
# Epoch 20/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1182 - MAPE: 12.3616 - RMSE: 0.9677 - val_loss: 0.0736 - val_MAPE: 8.2316 - val_RMSE: 0.4528
# Epoch 21/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1068 - MAPE: 11.2062 - RMSE: 0.8217 - val_loss: 0.0575 - val_MAPE: 6.2977 - val_RMSE: 0.3376
# Epoch 22/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1071 - MAPE: 10.4445 - RMSE: 0.7477 - val_loss: 0.0747 - val_MAPE: 8.2449 - val_RMSE: 0.4107
# Epoch 23/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1098 - MAPE: 11.7212 - RMSE: 0.8858 - val_loss: 0.0623 - val_MAPE: 6.8850 - val_RMSE: 0.3712
# Epoch 24/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0978 - MAPE: 10.5139 - RMSE: 0.8445 - val_loss: 0.0699 - val_MAPE: 7.7300 - val_RMSE: 0.4001
# Epoch 25/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.1025 - MAPE: 10.9262 - RMSE: 0.8566 - val_loss: 0.0969 - val_MAPE: 10.8550 - val_RMSE: 0.5286
# Epoch 26/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1007 - MAPE: 10.5949 - RMSE: 0.8154 - val_loss: 0.0608 - val_MAPE: 6.6802 - val_RMSE: 0.3567
# Epoch 27/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.1019 - MAPE: 10.2656 - RMSE: 0.7513 - val_loss: 0.0570 - val_MAPE: 6.2618 - val_RMSE: 0.3409
# Epoch 28/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0923 - MAPE: 9.6024 - RMSE: 0.7448 - val_loss: 0.0561 - val_MAPE: 6.1141 - val_RMSE: 0.3265
# Epoch 29/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0951 - MAPE: 10.3832 - RMSE: 0.7889 - val_loss: 0.0606 - val_MAPE: 6.6434 - val_RMSE: 0.3482
# Epoch 30/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0938 - MAPE: 9.6001 - RMSE: 0.7312 - val_loss: 0.0729 - val_MAPE: 8.0436 - val_RMSE: 0.4026
# Epoch 31/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0856 - MAPE: 8.7546 - RMSE: 0.6649 - val_loss: 0.0620 - val_MAPE: 6.8065 - val_RMSE: 0.3632
# Epoch 32/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0830 - MAPE: 8.6024 - RMSE: 0.6342 - val_loss: 0.0703 - val_MAPE: 7.7524 - val_RMSE: 0.4283
# Epoch 33/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0789 - MAPE: 8.0326 - RMSE: 0.5561 - val_loss: 0.0600 - val_MAPE: 6.2073 - val_RMSE: 0.3105
# Epoch 34/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0801 - MAPE: 8.3773 - RMSE: 0.6310 - val_loss: 0.0662 - val_MAPE: 7.2548 - val_RMSE: 0.3740
# Epoch 35/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0801 - MAPE: 8.3698 - RMSE: 0.6264 - val_loss: 0.0567 - val_MAPE: 6.1528 - val_RMSE: 0.3255
# Epoch 36/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0809 - MAPE: 8.4225 - RMSE: 0.6231 - val_loss: 0.0586 - val_MAPE: 6.2308 - val_RMSE: 0.3199
# Epoch 37/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0814 - MAPE: 8.7658 - RMSE: 0.6520 - val_loss: 0.0598 - val_MAPE: 6.1762 - val_RMSE: 0.3084
# Epoch 38/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0767 - MAPE: 7.7472 - RMSE: 0.5167 - val_loss: 0.0638 - val_MAPE: 6.9534 - val_RMSE: 0.3551
# Epoch 39/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0738 - MAPE: 7.8663 - RMSE: 0.5764 - val_loss: 0.0573 - val_MAPE: 6.0420 - val_RMSE: 0.3050
# Epoch 40/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0703 - MAPE: 7.4882 - RMSE: 0.5483 - val_loss: 0.0580 - val_MAPE: 6.1647 - val_RMSE: 0.3123
# Epoch 41/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0680 - MAPE: 6.8840 - RMSE: 0.4491 - val_loss: 0.0592 - val_MAPE: 6.4932 - val_RMSE: 0.3450
# Epoch 42/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0724 - MAPE: 7.5730 - RMSE: 0.5954 - val_loss: 0.0648 - val_MAPE: 7.0991 - val_RMSE: 0.3598
# Epoch 43/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0699 - MAPE: 7.1304 - RMSE: 0.4876 - val_loss: 0.0667 - val_MAPE: 6.9062 - val_RMSE: 0.3519
# Epoch 44/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0683 - MAPE: 7.0887 - RMSE: 0.4848 - val_loss: 0.0570 - val_MAPE: 6.0509 - val_RMSE: 0.3093
# Epoch 45/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0722 - MAPE: 7.2531 - RMSE: 0.5101 - val_loss: 0.0934 - val_MAPE: 10.3921 - val_RMSE: 0.4940
# Epoch 46/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0657 - MAPE: 6.9027 - RMSE: 0.4555 - val_loss: 0.0662 - val_MAPE: 7.3048 - val_RMSE: 0.3782
# Epoch 47/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0661 - MAPE: 6.7141 - RMSE: 0.4602 - val_loss: 0.0533 - val_MAPE: 5.7044 - val_RMSE: 0.2981
# Epoch 48/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0631 - MAPE: 6.4245 - RMSE: 0.4165 - val_loss: 0.0625 - val_MAPE: 6.5915 - val_RMSE: 0.3340
# Epoch 49/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0631 - MAPE: 6.4571 - RMSE: 0.4499 - val_loss: 0.0721 - val_MAPE: 7.1981 - val_RMSE: 0.3431
# Epoch 50/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0643 - MAPE: 6.7151 - RMSE: 0.4367 - val_loss: 0.0554 - val_MAPE: 5.9314 - val_RMSE: 0.3082
# Epoch 51/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0608 - MAPE: 6.1749 - RMSE: 0.4024 - val_loss: 0.0573 - val_MAPE: 6.1908 - val_RMSE: 0.3231
# Epoch 52/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0585 - MAPE: 6.1743 - RMSE: 0.4098 - val_loss: 0.0568 - val_MAPE: 6.0690 - val_RMSE: 0.3136
# Epoch 53/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0575 - MAPE: 5.8903 - RMSE: 0.3735 - val_loss: 0.0579 - val_MAPE: 6.0456 - val_RMSE: 0.3059
# Epoch 54/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0617 - MAPE: 6.2974 - RMSE: 0.3942 - val_loss: 0.0620 - val_MAPE: 6.7268 - val_RMSE: 0.3436
# Epoch 55/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0580 - MAPE: 5.9653 - RMSE: 0.3687 - val_loss: 0.0561 - val_MAPE: 5.9306 - val_RMSE: 0.3059
# Epoch 56/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0631 - MAPE: 6.5101 - RMSE: 0.4087 - val_loss: 0.0541 - val_MAPE: 5.7120 - val_RMSE: 0.2916
# Epoch 57/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0568 - MAPE: 5.8518 - RMSE: 0.3623 - val_loss: 0.0537 - val_MAPE: 5.7074 - val_RMSE: 0.2974
# Epoch 58/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0572 - MAPE: 5.8943 - RMSE: 0.3609 - val_loss: 0.0608 - val_MAPE: 6.2652 - val_RMSE: 0.3154
# Epoch 59/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0586 - MAPE: 6.0805 - RMSE: 0.3731 - val_loss: 0.0592 - val_MAPE: 6.2280 - val_RMSE: 0.3189
# Epoch 60/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0552 - MAPE: 5.5767 - RMSE: 0.3438 - val_loss: 0.0545 - val_MAPE: 5.7565 - val_RMSE: 0.2971
# Epoch 61/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0543 - MAPE: 5.5627 - RMSE: 0.3403 - val_loss: 0.0662 - val_MAPE: 6.8801 - val_RMSE: 0.3448
# Epoch 62/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0525 - MAPE: 5.3980 - RMSE: 0.3309 - val_loss: 0.0619 - val_MAPE: 6.4057 - val_RMSE: 0.3230
# Epoch 63/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0556 - MAPE: 5.7385 - RMSE: 0.3440 - val_loss: 0.0698 - val_MAPE: 7.0794 - val_RMSE: 0.3473
# Epoch 64/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0510 - MAPE: 5.2423 - RMSE: 0.2984 - val_loss: 0.0657 - val_MAPE: 6.7107 - val_RMSE: 0.3298
# Epoch 65/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0526 - MAPE: 5.3594 - RMSE: 0.3176 - val_loss: 0.0569 - val_MAPE: 6.1254 - val_RMSE: 0.3214
# Epoch 66/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0507 - MAPE: 5.2317 - RMSE: 0.3064 - val_loss: 0.0560 - val_MAPE: 5.8083 - val_RMSE: 0.2938
# Epoch 67/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0547 - MAPE: 5.5928 - RMSE: 0.3234 - val_loss: 0.0590 - val_MAPE: 6.1364 - val_RMSE: 0.3096
# Epoch 68/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0536 - MAPE: 5.4456 - RMSE: 0.3124 - val_loss: 0.0562 - val_MAPE: 5.9705 - val_RMSE: 0.3072
# Epoch 69/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0495 - MAPE: 5.0254 - RMSE: 0.2863 - val_loss: 0.0690 - val_MAPE: 6.9542 - val_RMSE: 0.3384
# Epoch 70/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0492 - MAPE: 5.0266 - RMSE: 0.2814 - val_loss: 0.0592 - val_MAPE: 6.1224 - val_RMSE: 0.3059
# Epoch 71/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0486 - MAPE: 5.0114 - RMSE: 0.2962 - val_loss: 0.0592 - val_MAPE: 6.1998 - val_RMSE: 0.3151
# Epoch 72/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0474 - MAPE: 4.8561 - RMSE: 0.2774 - val_loss: 0.0541 - val_MAPE: 5.7400 - val_RMSE: 0.3017
# Epoch 73/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0483 - MAPE: 4.9577 - RMSE: 0.2749 - val_loss: 0.0723 - val_MAPE: 7.2842 - val_RMSE: 0.3400
# Epoch 74/100
# 33/33 [==============================] - 0s 13ms/step - loss: 0.0475 - MAPE: 4.8026 - RMSE: 0.2682 - val_loss: 0.0658 - val_MAPE: 6.6627 - val_RMSE: 0.3232
# Epoch 75/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0470 - MAPE: 4.7931 - RMSE: 0.2691 - val_loss: 0.0638 - val_MAPE: 6.5305 - val_RMSE: 0.3239
# Epoch 76/100
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0519 - MAPE: 5.3555 - RMSE: 0.3151 - val_loss: 0.0540 - val_MAPE: 5.6765 - val_RMSE: 0.2918
# Epoch 77/100
# 31/33 [===========================>..] - ETA: 0s - loss: 0.0460 - MAPE: 4.7338 - RMSE: 0.2749Restoring model weights from the end of the best epoch.
# 33/33 [==============================] - 0s 14ms/step - loss: 0.0459 - MAPE: 4.7097 - RMSE: 0.2725 - val_loss: 0.0600 - val_MAPE: 6.1708 - val_RMSE: 0.3079
# Epoch 00077: early stopping
# [INFO] Time = 101.98

# %% [markdown]
# ## Training performance

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(20, 4))

ax[0].plot( score.history['RMSE']     );
ax[0].plot( score.history['val_RMSE'] );
ax[0].legend(['Training', 'Validation'], frameon=False);
ax[0].set_xlabel('Epochs');
ax[0].set_ylabel('RMSE');

ax[1].plot( score.history['MAPE']     );
ax[1].plot( score.history['val_MAPE'] );
ax[1].legend(['Training', 'Validation'], frameon=False);
ax[1].set_xlabel('Epochs');
ax[1].set_ylabel('MAPE');

# %% [markdown]
# ## Save forecasting model

# %%
# Save model
#
model.save('models/TCN.hdf5')

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Get predictions

# %%
y_pred = model.predict( testX )

# %% [markdown]
# ### Calculate Performance on Testing set - Prediction visualization

# %%
for idx, feature in enumerate(Features):
    
    print('[INFO] Feature: ', feature)
    print('------------------------------------------------')
    Performance_Foresting_Model = {'RMSE': [], 'MAE': [], 'SMAPE': [], 'R2' : []}

    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
        
        
        
        # Evaluation
        #
        MAE, RMSE, MAPE, SMAPE, R2 = RegressionEvaluation( Prices )
        
        # Store results
        #
        Performance_Foresting_Model['RMSE']    += [ RMSE    ]
        Performance_Foresting_Model['MAE']     += [ MAE     ]
        Performance_Foresting_Model['SMAPE']   += [ SMAPE   ]
        Performance_Foresting_Model['R2']      += [ R2      ]
        
        # Present results
        #
        print('Horizon: ', i)
        print('> RMSE:  ', RMSE)
        print('> SMAPE: ', SMAPE)
        print('> R2:    ', R2)
        print()
# Out:
# [INFO] Feature:  Temperature [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   7.9178194289209
# > SMAPE:  8.617917504299822
# > R2:     -0.05684089639300405
#
# Horizon:  1
# > RMSE:   13.258224447558602
# > SMAPE:  15.462738287269357
# > R2:     -1.904400671064724
#
# Horizon:  2
# > RMSE:   8.987721319478776
# > SMAPE:  9.74094890450286
# > R2:     -0.32820476298174595
#
# [INFO] Feature:  DewPoint [Fahrenheit]
# ------------------------------------------------
# Horizon:  0
# > RMSE:   7.976547132477904
# > SMAPE:  11.515133873274193
# > R2:     0.020097455305019607
#
# Horizon:  1
# > RMSE:   9.94328724085317
# > SMAPE:  15.13897824861365
# > R2:     -0.5209654045440173
#
# Horizon:  2
# > RMSE:   9.13525741209347
# > SMAPE:  13.731867742958556
# > R2:     -0.28638668454692384

# %% [markdown]
# ## Visualization

# %%
for idx, feature in enumerate(Features):
    
    for i in range( Horizon ):
    
        Prices = pd.DataFrame([])        

        Prices['Real']       = testY[:,  i, idx]
        Prices['Prediction'] = y_pred[:, i, idx]

        # Apply inverse transformation   
        #
        if (Transformation == True):
            Prices = np.exp( Prices ) - Value
            
            
            
        # Plot Real & Predicted values
        #
        Prices.plot( figsize = (20, 3) )
        #
        plt.title('Feature: {} - Horizon = {}'.format(feature, i+1))
        plt.legend( frameon = False, fontsize = 14)
        plt.xticks(size = 12)
        plt.yticks(size = 12)
        plt.show()
